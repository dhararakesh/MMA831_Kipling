# %%
#import necessary packages
from sqlalchemy import create_engine
import pandas as pd
from sqlalchemy import select
import pymysql
import sqlalchemy as db
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# "C:\\Users\\anush\\OneDrive\\Queen's Uni\\Marketing Analytics - MMA 831\\Project"

# %%
df_shang = pd.read_csv("./product features//831_shangeri_features_product_level.csv")

# %%
df_shang.head()
# Out:
#                          product_id  percentage_weekday_products  \
# 0  00066f42aeeb9f3007548bb9d3f33c38                          0.0
# 1  00088930e925c41fd95ebfe695fd2655                        100.0
# 2  0009406fd7479715e4bef61dd91f2462                        100.0
# 3  000b8f95fcb9e0096488278317764d19                        100.0
# 4  000d9be29b5207b54e86aa1b1ac54872                        100.0
#
#    percentage_daytime_products
# 0                          0.0
# 1                          0.0
# 2                        100.0
# 3                         50.0
# 4                        100.0

# %%
df_rakesh = pd.read_csv("./product features//831_rakesh_features.csv")

# %%
df_rakesh.head()
# Out:
#                          product_id product_category_name_english  \
# 0  00066f42aeeb9f3007548bb9d3f33c38                     perfumery
# 1  00088930e925c41fd95ebfe695fd2655                          auto
# 2  0009406fd7479715e4bef61dd91f2462                bed_bath_table
# 3  000b8f95fcb9e0096488278317764d19                    housewares
# 4  000d9be29b5207b54e86aa1b1ac54872                 watches_gifts
#
#   product_super_category_name  units_sold  revenue  avg_price  \
# 0                     fashion           1   101.65     101.65
# 1             tools_or_repair           1   129.90     129.90
# 2                   household           1   229.00     229.00
# 3                   household           2   117.80      58.90
# 4                  technology           1   199.00     199.00
#
#    avg_delivery_time_days  sellers  units_sold_per_seller  avg_review_score
# 0                    18.0        1                    1.0               5.0
# ...

# %%
df_melody = pd.read_csv("./product features//melody_product_features.csv")

# %%
df_melody.head()
# Out:
#                          product_id  photo_effect
# 0  00066f42aeeb9f3007548bb9d3f33c38             1
# 1  00088930e925c41fd95ebfe695fd2655             1
# 2  0009406fd7479715e4bef61dd91f2462             0
# 3  000b8f95fcb9e0096488278317764d19             2
# 4  000d9be29b5207b54e86aa1b1ac54872             1

# %%
#merge with both on product_id
df_merged_first = pd.merge(df_shang, df_rakesh, left_on='product_id', right_on = 'product_id', how='outer')
df_merged_first.head(100)
# Out:
#                           product_id  percentage_weekday_products  \
# 0   00066f42aeeb9f3007548bb9d3f33c38                       0.0000
# 1   00088930e925c41fd95ebfe695fd2655                     100.0000
# 2   0009406fd7479715e4bef61dd91f2462                     100.0000
# 3   000b8f95fcb9e0096488278317764d19                     100.0000
# 4   000d9be29b5207b54e86aa1b1ac54872                     100.0000
# ..                               ...                          ...
# 95  00d93a09990b319a7c946ed7a8c67656                       0.0000
# 96  00dc8a1b2de45a7fca5921544e5f351d                       0.0000
# 97  00ddaddbe03b7103d80daee96892363f                     100.0000
# 98  00de606a5dda99c2499f94ef18282977                     100.0000
# 99  00de7f393d962717eeeb2d7131a40dba                      77.7778
#
#     percentage_daytime_products product_category_name_english  \
# 0                        0.0000                     perfumery
# ...

# %%
#merge with both on product_id
df_merged = pd.merge(df_merged_first, df_melody, left_on='product_id', right_on = 'product_id', how='outer')
df_merged.head(100)
# Out:
#                           product_id  percentage_weekday_products  \
# 0   00066f42aeeb9f3007548bb9d3f33c38                       0.0000
# 1   00088930e925c41fd95ebfe695fd2655                     100.0000
# 2   0009406fd7479715e4bef61dd91f2462                     100.0000
# 3   000b8f95fcb9e0096488278317764d19                     100.0000
# 4   000d9be29b5207b54e86aa1b1ac54872                     100.0000
# ..                               ...                          ...
# 95  00d93a09990b319a7c946ed7a8c67656                       0.0000
# 96  00dc8a1b2de45a7fca5921544e5f351d                       0.0000
# 97  00ddaddbe03b7103d80daee96892363f                     100.0000
# 98  00de606a5dda99c2499f94ef18282977                     100.0000
# 99  00de7f393d962717eeeb2d7131a40dba                      77.7778
#
#     percentage_daytime_products product_category_name_english  \
# 0                        0.0000                     perfumery
# ...

# %%
df_merged.to_csv('831_final_product_level_dataset.csv', index=False)
