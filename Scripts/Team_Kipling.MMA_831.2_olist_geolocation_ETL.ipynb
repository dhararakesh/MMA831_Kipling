# %%
import pandas as pd
import os as os
import pandasql as psql
from pandasql import sqldf
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import pymysql
import pandas as pd

#Set max display rows for EDA
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

path = r"C:\Users\anush\OneDrive\Queen's Uni\Marketing Analytics - MMA 831\Project\dataset\olist_geolocation_dataset.csv"
data = pd.read_csv(path, dtype=str)

# %%
data.head(100)
# Out:
#    geolocation_zip_code_prefix      geolocation_lat      geolocation_lng  \
# 0                        01037   -23.54562128115268   -46.63929204800168
# 1                        01046  -23.546081127035535   -46.64482029837157
# 2                        01046   -23.54612896641469   -46.64295148361138
# 3                        01041    -23.5443921648681   -46.63949930627844
# 4                        01035  -23.541577961711493   -46.64160722329613
# 5                        01012  -23.547762303364266   -46.63536053788448
# 6                        01047  -23.546273112412678   -46.64122516971552
# 7                        01013  -23.546923208436723    -46.6342636964915
# 8                        01029  -23.543769055769133   -46.63427784085132
# 9                        01011  -23.547639550320632   -46.63603162315495
# 10                       01013  -23.547325128224376   -46.63418378613892
# 11                       01032   -23.53841810407414  -46.634778375266734
# 12                       01014  -23.546435343326205   -46.63383023397196
# 13                       01012  -23.548945985189434   -46.63467113292871
# 14                       01037  -23.545187340816042   -46.63785524104107
# 15                       01046  -23.546081127035535   -46.64482029837157
# 16                       01039  -23.541883009983316   -46.63991946670314
# 17                       01024  -23.541389521053937  -46.629899087812184
# 18                       01009   -23.54693540437998   -46.63658792659698
# 19                       01046  -23.545884279214015  -46.643163191240035
# 20                       01046  -23.545165891770928  -46.643785796266464
# 21                       01020   -23.55223547100232    -46.6284406588955
# 22                       01011  -23.546690486964888  -46.635446958807194
# 23                       01043  -23.546656718016017   -46.64078762115524
# 24                       01050  -23.549773516504185   -46.64559900666509
# 25                       01045  -23.541593762969626   -46.64189378810082
# 26                       01009  -23.545429533441073   -46.63571531432852
# 27                       01007  -23.550392524842728  -46.637301640717844
# 28                       01032    -23.5398418758395   -46.63514797691531
# 29                       01041  -23.543539449073783   -46.64057731057763
# 30                       01005  -23.549819091869107   -46.63560588995324
# 31                       01037  -23.546704599774962   -46.64033633250615
# 32                       01017   -23.55001091199737   -46.63116636914989
# 33                       01046   -23.54532011933758   -46.64406863434122
# 34                       01019  -23.552151883432384   -46.63080224715792
# 35                       01032  -23.540774688874112   -46.63551484303775
# 36                       01017    -23.5492954052167   -46.63207469510652
# 37                       01050  -23.549009406053422  -46.642812281839745
# 38                       01050  -23.548755593946588  -46.642789203733535
# 39                       01027  -23.538301166801343   -46.63076391104508
# 40                       01050   -23.54985418067981  -46.643139396906825
# 41                       01013  -23.547119249235397  -46.634232699405686
# 42                       01033   -23.54032130474925  -46.636394815973325
# 43                       01009   -23.54569153926945  -46.635866061486446
# 44                       01046  -23.546081127035535   -46.64482029837157
# 45                       01050   -23.54874766250217   -46.64239136704376
# 46                       01032  -23.541191476542252   -46.63499346058632
# 47                       01020  -23.552549496537548   -46.63163152553523
# 48                       01006   -23.55052430835593   -46.63669363835193
# 49                       01034  -23.542391627195926   -46.63770927785183
# 50                       01020  -23.552482452132203   -46.62938955675458
# 51                       01047   -23.54660531805078  -46.641982174447385
# 23        são paulo                SP
# 24        sao paulo                SP
# 25        sao paulo                SP
# 26        sao paulo                SP
# 27        sao paulo                SP
# 28        são paulo                SP
# 29        sao paulo                SP
# 30        sao paulo                SP
# 31        são paulo                SP
# 32        são paulo                SP
# 33        sao paulo                SP
# 34        sao paulo                SP
# 35        sao paulo                SP
# 36        sao paulo                SP
# 37        sao paulo                SP
# 38        sao paulo                SP
# 39        sao paulo                SP
# 40        sao paulo                SP
# 41        sao paulo                SP
# 42        sao paulo                SP
# 43        sao paulo                SP
# 44        sao paulo                SP
# 45        sao paulo                SP
# 46        sao paulo                SP
# 47        sao paulo                SP
# 48        sao paulo                SP
# 49        sao paulo                SP
# 50        sao paulo                SP
# 51        sao paulo                SP
# 52        sao paulo                SP
# 53        sao paulo                SP
# 54        sao paulo                SP
# 55        sao paulo                SP
# 56        sao paulo                SP
# 57        são paulo                SP
# 58        sao paulo                SP
# 59        sao paulo                SP
# 60        sao paulo                SP
# 61        sao paulo                SP
# 62        são paulo                SP
# 63        sao paulo                SP
# 64        sao paulo                SP
# 65        sao paulo                SP
# 66        sao paulo                SP
# 67        sao paulo                SP
# 68        são paulo                SP
# 69        sao paulo                SP
# 70        sao paulo                SP
# 71        são paulo                SP
# 72        sao paulo                SP
# 73        sao paulo                SP
# 74        sao paulo                SP
# 75        sao paulo                SP
# 76        sao paulo                SP
# 77        sao paulo                SP
# 78        sao paulo                SP
# 79        sao paulo                SP
# 80        sao paulo                SP
# 81        sao paulo                SP
# 82        sao paulo                SP
# 83        sao paulo                SP
# 84        sao paulo                SP
# 85        sao paulo                SP
# 86        são paulo                SP
# 87        sao paulo                SP
# 88        sao paulo                SP
# 89        sao paulo                SP
# 90        sao paulo                SP
# 91        sao paulo                SP
# 92        sao paulo                SP
# 93        são paulo                SP
# 94        sao paulo                SP
# 95        sao paulo                SP
# 96        são paulo                SP
# 97        sao paulo                SP
# 98        são paulo                SP
# 99        sao paulo                SP

# %%
#Check for null values
nullcheck = data.isnull().sum()
nullcheck
#no null
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
data.dtypes
#data type seems fine. no data type transformation needed
# Out:
# geolocation_zip_code_prefix    object
# geolocation_lat                object
# geolocation_lng                object
# geolocation_city               object
# geolocation_state              object
# dtype: object

# %%
index = data.index
number_of_rows = len(index)
number_of_rows
# Out:
# 1000163

# %%
#payment_sequential and order id is foreign key!
data.groupby(['geolocation_zip_code_prefix', 'geolocation_lat','geolocation_lng', 'geolocation_city' ]).ngroups
# Out:
# 738330

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

#export dataframe into MySQL table
tableName   = "olist_geolocation"          

sqlEngine       = create_engine('mysql+pymysql://admin:m0mDba4r6y@mma860-teamkipling.ci9pdpp0ny8u.us-east-2.rds.amazonaws.com:3308/MMA_831', pool_recycle = -1)
dbConnection    = sqlEngine.connect()

try:
    frame           = data.to_sql(tableName, dbConnection, if_exists='replace', index=False);
except ValueError as vx:
    print(vx)
except Exception as ex:   
    print(ex)
else:
    print("Table %s created successfully."%tableName);   
finally:
    dbConnection.close()
# Out:
# Table olist_geolocation created successfully.
