# %%
import pandas as pd
import os as os
import pandasql as psql
from pandasql import sqldf
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import pymysql
import pandas as pd

#Set max display rows for EDA
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

path = r"C:\Users\anush\OneDrive\Queen's Uni\Marketing Analytics - MMA 831\Project\dataset\olist_orders_dataset.csv"
data = pd.read_csv(path)

# %%
data.head(100)
# Out:
#                             order_id                       customer_id  \
# 0   e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1   53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2   47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3   949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4   ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5   a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6   136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7   6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8   76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9   e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
# 10  e6ce16cb79ec1d90b1da9085a6118aeb  494dded5b201313c64ed7f100595b95c
# 11  34513ce0c4fab462a55830c0989c7edb  7711cf624183d843aafe81855097bc37
# ...

# %%
#data = data.head(10)
#data

# %%
#Check for null values
nullcheck = data.isnull().sum()
nullcheck
#no null
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
index = data.index
number_of_rows = len(index)
number_of_rows
# Out:
# 99441

# %%
#len(data['order_id'].unique().tolist())
#order id is primary key!
data.groupby(['order_id']).ngroups
# Out:
# 99441

# %%
#convert OrderDt to date
data['order_purchase_timestamp'] = pd.to_datetime(data['order_purchase_timestamp'], format="%Y-%m-%d %H:%M:%S")
data['order_purchase_timestamp'].head(10)
# Out:
# 0   2017-10-02 10:56:33
# 1   2018-07-24 20:41:37
# 2   2018-08-08 08:38:49
# 3   2017-11-18 19:28:06
# 4   2018-02-13 21:18:39
# 5   2017-07-09 21:57:05
# 6   2017-04-11 12:22:08
# 7   2017-05-16 13:10:30
# 8   2017-01-23 18:29:09
# 9   2017-07-29 11:55:02
# Name: order_purchase_timestamp, dtype: datetime64[ns]

# %%
data['order_approved_at'] = pd.to_datetime(data['order_approved_at'], format="%Y-%m-%d %H:%M:%S")
data['order_approved_at'].head(10)
# Out:
# 0   2017-10-02 11:07:15
# 1   2018-07-26 03:24:27
# 2   2018-08-08 08:55:23
# 3   2017-11-18 19:45:59
# 4   2018-02-13 22:20:29
# 5   2017-07-09 22:10:13
# 6   2017-04-13 13:25:17
# 7   2017-05-16 13:22:11
# 8   2017-01-25 02:50:47
# 9   2017-07-29 12:05:32
# Name: order_approved_at, dtype: datetime64[ns]

# %%
data['order_delivered_carrier_date'] = pd.to_datetime(data['order_delivered_carrier_date'], format="%Y-%m-%d %H:%M:%S")
data['order_delivered_carrier_date'].head(10)
# Out:
# 0   2017-10-04 19:55:00
# 1   2018-07-26 14:31:00
# 2   2018-08-08 13:50:00
# 3   2017-11-22 13:39:59
# 4   2018-02-14 19:46:34
# 5   2017-07-11 14:58:04
# 6                   NaT
# 7   2017-05-22 10:07:46
# 8   2017-01-26 14:16:31
# 9   2017-08-10 19:45:24
# Name: order_delivered_carrier_date, dtype: datetime64[ns]

# %%
data['order_delivered_customer_date'] = pd.to_datetime(data['order_delivered_customer_date'], format="%Y-%m-%d %H:%M:%S")
data['order_delivered_customer_date'].head(10)
# Out:
# 0   2017-10-10 21:25:13
# 1   2018-08-07 15:27:45
# 2   2018-08-17 18:06:29
# 3   2017-12-02 00:28:42
# 4   2018-02-16 18:17:02
# 5   2017-07-26 10:57:55
# 6                   NaT
# 7   2017-05-26 12:55:51
# 8   2017-02-02 14:08:10
# 9   2017-08-16 17:14:30
# Name: order_delivered_customer_date, dtype: datetime64[ns]

# %%
data['order_estimated_delivery_date'] = pd.to_datetime(data['order_estimated_delivery_date'], format="%Y-%m-%d %H:%M:%S")
data['order_estimated_delivery_date'].head(10)
# Out:
# 0   2017-10-18
# 1   2018-08-13
# 2   2018-09-04
# 3   2017-12-15
# 4   2018-02-26
# 5   2017-08-01
# 6   2017-05-09
# 7   2017-06-07
# 8   2017-03-06
# 9   2017-08-23
# Name: order_estimated_delivery_date, dtype: datetime64[ns]

# %%
data.dtypes
#data type seems fine. no data type transformation needed
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

#export dataframe into MySQL table
tableName   = "olist_orders"          

sqlEngine       = create_engine('mysql+pymysql://admin:m0mDba4r6y@mma860-teamkipling.ci9pdpp0ny8u.us-east-2.rds.amazonaws.com:3308/MMA_831', pool_recycle = -1)
dbConnection    = sqlEngine.connect()

try:
    frame           = data.to_sql(tableName, dbConnection, if_exists='replace', index=False);
except ValueError as vx:
    print(vx)
except Exception as ex:   
    print(ex)
else:
    print("Table %s created successfully."%tableName);   
finally:
    dbConnection.close()
# Out:
# Table olist_orders created successfully.
