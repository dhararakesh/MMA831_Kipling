# %%
import pandas as pd
import os as os
import pandasql as psql
from pandasql import sqldf
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import pymysql
import pandas as pd

#Set max display rows for EDA
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

path = r"C:\Users\anush\OneDrive\Queen's Uni\Marketing Analytics - MMA 831\Project\dataset\product_category_name_translation.csv"
data = pd.read_csv(path)

# %%
data.head(200)
# Out:
#                              product_category_name  \
# 0                                     beleza_saude
# 1                           informatica_acessorios
# 2                                       automotivo
# 3                                  cama_mesa_banho
# 4                                 moveis_decoracao
# 5                                    esporte_lazer
# 6                                       perfumaria
# 7                            utilidades_domesticas
# 8                                        telefonia
# 9                               relogios_presentes
# 10                               alimentos_bebidas
# 11                                           bebes
# 12                                       papelaria
# 13                        tablets_impressao_imagem
# 14                                      brinquedos
# 15                                  telefonia_fixa
# 16                              ferramentas_jardim
# ...

# %%
#Check for null values
nullcheck = data.isnull().sum()
nullcheck
#no null
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
index = data.index
number_of_rows = len(index)
number_of_rows
# Out:
# 71

# %%
#len(data['order_id'].unique().tolist())
#order id is primary key!
data.groupby(['product_category_name']).ngroups
# Out:
# 71

# %%
data.dtypes
#data type seems fine. no data type transformation needed
# Out:
# product_category_name            object
# product_category_name_english    object
# dtype: object

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

#export dataframe into MySQL table
tableName   = "olist_product_category_name"          

sqlEngine       = create_engine('mysql+pymysql://admin:m0mDba4r6y@mma860-teamkipling.ci9pdpp0ny8u.us-east-2.rds.amazonaws.com:3308/MMA_831', pool_recycle = -1)
dbConnection    = sqlEngine.connect()

try:
    frame           = data.to_sql(tableName, dbConnection, if_exists='replace', index=False);
except ValueError as vx:
    print(vx)
except Exception as ex:   
    print(ex)
else:
    print("Table %s created successfully."%tableName);   
finally:
    dbConnection.close()
# Out:
# Table olist_product_category_name created successfully.
