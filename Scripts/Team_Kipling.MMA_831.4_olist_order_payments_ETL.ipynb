# %%
import pandas as pd
import os as os
import pandasql as psql
from pandasql import sqldf
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import pymysql
import pandas as pd

#Set max display rows for EDA
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

path = r"C:\Users\anush\OneDrive\Queen's Uni\Marketing Analytics - MMA 831\Project\dataset\olist_order_payments_dataset.csv"
data = pd.read_csv(path)

# %%
data.head(100)
# Out:
#                             order_id  payment_sequential payment_type  \
# 0   b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1   a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2   25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3   ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4   42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# 5   298fcdf1f73eb413e4d26d01b25bc1cd                   1  credit_card
# 6   771ee386b001f06208a7419e4fc1bbd7                   1  credit_card
# 7   3d7239c394a212faae122962df514ac7                   1  credit_card
# 8   1f78449c87a54faf9e96e88ba1491fa9                   1  credit_card
# 9   0573b5e23cbd798006520e1d5b4c6714                   1       boleto
# 10  d88e0d5fa41661ce03cf6cf336527646                   1  credit_card
# 11  2480f727e869fdeb397244a21b721b67                   1  credit_card
# ...

# %%
#Check for null values
nullcheck = data.isnull().sum()
nullcheck
#no null
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
index = data.index
number_of_rows = len(index)
number_of_rows
# Out:
# 103886

# %%
#len(data['order_id'].unique().tolist())
#payment_sequential and order id is foreign key!
data.groupby(['order_id', 'payment_sequential']).ngroups
# Out:
# 103886

# %%
data.dtypes
#data type seems fine. no data type transformation needed
# Out:
# order_id                 object
# payment_sequential        int64
# payment_type             object
# payment_installments      int64
# payment_value           float64
# dtype: object

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

#export dataframe into MySQL table
tableName   = "olist_order_payments"          

sqlEngine       = create_engine('mysql+pymysql://admin:m0mDba4r6y@mma860-teamkipling.ci9pdpp0ny8u.us-east-2.rds.amazonaws.com:3308/MMA_831', pool_recycle = -1)
dbConnection    = sqlEngine.connect()

try:
    frame           = data.to_sql(tableName, dbConnection, if_exists='replace', index=False);
except ValueError as vx:
    print(vx)
except Exception as ex:   
    print(ex)
else:
    print("Table %s created successfully."%tableName);   
finally:
    dbConnection.close()
# Out:
# Table olist_order_payments created successfully.
